# %% [markdown]
# ** Exercise 1: Understanding Data Visualization**

# %% [markdown]
# Task: Explain why data visualization is important in data analysis:
#     -visualiser les patterns
#     -comprendre la donnée, les trend
#
#
# Task: Describe the purpose of a line graph in data visualization:
#     -

# %% [markdown]
#  Exercise 2: Creating a Line Plot for Temperature Variation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
x = ['monday', 'tuesday', 'wednesday', 'thurday', 'firday', 'saturday', 'sunday']
y = [72, 74, 76, 80, 82, 78, 75]
plt.plot(x, y)
plt.title('temperature value for each day' )
plt.show()

# %% [markdown]
# Exercise 3: Visualizing Monthly Sales with a Bar Chart

# %%
x = ["January", "February", "March" ]
y = [5000, 7500, 6200, ]
plt.xlabel('month')
plt.ylabel('day')
plt.title('sales values')
plt.bar(x, y)
plt.show()

# %% [markdown]
# Exercise 4: Visualizing the Distribution of CGPA

# %% [markdown]
# etapes:1-create data = CGPA
#         2-dataframe
#         3-histo

# %%
data =  {'CGPA' :[ 12, 14, 18, 9, 11,10]}
df = pd.DataFrame(data, index=None)

# %%
sns.histplot(df['CGPA'], bins=8, color='skyblue')
plt.title('Histogram of CGPA')
plt.xlabel("CGPA")
plt.ylabel("Nombre d'étudiants")
plt.show()

# %% [markdown]
#  Exercice 5 : Comparer les niveaux d'anxiété entre les sexes

# %%
data = {
    'gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F'],
    'anxiety': ['true', 'true', 'true', 'false', 'true', 'true', 'true', 'false']
}
df = pd.DataFrame(data)

# %% [markdown]
# graphique a bar sur seaborn

# %%
sns.countplot(x='gender', hue='anxiety', data=df, palette='pink')
plt.xlabel('Genre')
plt.ylabel('Nombre d\'individus')
plt.show()

# %%
sns.histplot(df ['anxiety'], bins=16, color='skyblue')
plt.title('Histogram of anxiety')
plt.show()

# %% [markdown]
# Exercise 6: Exploring the Relationship Between Age and Panic Attacks

# %%
data = {'Age': [18, 21, 22, 19, 24, 30, 28, 35, 40, 45],
        'Panic Attacks?': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No']}
df = pd.DataFrame(data)

# Conversion des réponses en valeurs numériques
df['Panic_Attack'] = df['Panic Attacks?'].map({'Yes': 1, 'No': 0})

sns.scatterplot(x=df['Age'], y=df['Panic_Attack'], color='red', marker='o', s=100)
plt.xlabel('Age')
plt.ylabel('Panic Attacks (0 = No, 1 = Yes)')
plt.title('Relation entre l\'âge et les crises de panique')
plt.grid(True)

# Affichage du graphique
plt.show()
