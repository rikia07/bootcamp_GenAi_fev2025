# %% [markdown]
# 1. Create a histogram of customer spending from the tips dataset. Customize the bins and color.
#
# 2. Use pairplot on the iris dataset with different markers for species.
#
# 3. Visualize correlations in the iris dataset using a heatmap.
#
# 4. Build a FacetGrid using the titanic dataset to compare survival rates by age across class and gender.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# telecharge la dataset depui seaborn

# %%
data_tips = sns.load_dataset('tips')

# %%
data_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data_tips['total_bill'], bins=10, color='yellow')
plt.title('Histogram of Total Bill')
plt.show()

# %% [markdown]
# Use pairplot on the iris dataset with different markers for species.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species', palette='Dark2')
plt.show()

# %% [markdown]
#  Visualize correlations in the iris dataset using a heatmap.

# %% [markdown]
#  Build a FacetGrid using the titanic dataset to compare survival rates by age across class and gender.

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
g = sns.FacetGrid(data, col='sex', row='class', margin_titles=True)
g.map(sns.hisplot, 'total_bill', 'tip', color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 g = sns.FacetGrid(data, col='sex', row='class', margin_titles=True)
# ----> 2 g.map(sns.hisplot, 'total_bill', 'tip', color='red')
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'hisplot'
